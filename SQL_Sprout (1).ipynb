# %%
import numpy as np
import pandas as pd
import os

NUM_QUESTIONS = 10
myanswer = np.zeros(NUM_QUESTIONS, dtype=int)

myanswer[:] = [2, 3, 2, 3, 1, 1, 2, 2, 2, 4]


# Create DataFrame with correct column name

df = pd.DataFrame({
    "label": myanswer
})


# Save CSV

file_path = "submission.csv"
df.to_csv(file_path, index=False)

# Check if file exists

print("Saved file:", file_path)
print("Current files in folder:", os.listdir())
from google.colab import files
files.download("submission.csv")
# Out:
# Saved file: submission.csv
# Current files in folder: ['.config', 'submission.csv', 'drive', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
